# %%
import pandas as pd
df = pd.read_csv("/content/merged_transactions.csv")
df.head()
# Out:
#   product_id category  unit_price  is_discountable store_id store_type  \
# 0      P0200     Home      106.31                1     S007     Outlet
# 1      P0140  Grocery        9.13                1     S017     Street
# 2      P0225   Beauty       16.93                0     S038       Mall
# 3      P0105  Grocery       13.08                1     S039     Street
# 4      P0103     Home      143.33                1     S023       Mall
#
#     region        city customer_id gender  age loyalty_tier preferred_channel  \
# 0  Central   Grandview      C00010      M   42         Gold            Mobile
# 1  Central     Centrum      C00094      F   31       Silver           InStore
# 2    South   Southport      C00164      M   25       Silver           InStore
# 3     East  Rivermouth      C00197      F   24       Silver            Online
# 4     East  Rivermouth      C00104      M   25     Platinum           InStore
#
#   transaction_id transaction_date  channel  quantity  discount_pct
# 0       T0042714       2025-08-01  InStore         2           0.0
# 1       T0024445       2025-08-01  InStore         1           0.0
# 2       T0008413       2025-08-01   Online         2           0.0
# 3       T0037032       2025-08-01   Mobile         2           0.0
# 4       T0024521       2025-08-01  InStore         1           0.0

# %%
import pandas as pd

# --- Load your dataset ---
df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# --- Create a year-month column ---
df['year_month'] = df['transaction_date'].dt.to_period('M')

# --- Compute total amount spent ---
df['amount_spent'] = df['unit_price'] * df['quantity'] * (1 - df['discount_pct'])

# --- Select customer-level attributes (assumed constant per customer) ---
customer_features = df[['customer_id', 'gender', 'age', 'loyalty_tier', 'preferred_channel']].drop_duplicates()

# --- Group by customer, category, and month ---
monthly_summary = df.groupby(
    ['customer_id', 'category', 'year_month']
).agg(
    total_quantity=('quantity', 'sum'),
    total_spent=('amount_spent', 'sum'),
).reset_index()

# --- Merge static customer features back ---
final_df = monthly_summary.merge(customer_features, on='customer_id', how='left')

# Optional: convert 'year_month' to datetime
final_df['year_month'] = final_df['year_month'].astype(str)

print(final_df.head())
# Out:
#   customer_id  category year_month  total_quantity  total_spent gender  age  \
# 0      C00001    Beauty    2025-08               2      93.7700      M   41
# 1      C00001    Beauty    2025-09               2      65.0660      M   41
# 2      C00001    Beauty    2025-10               5     236.8900      M   41
# 3      C00001    Beauty    2025-12               5     105.3336      M   41
# 4      C00001  Clothing    2025-08               1     120.0000      M   41
#
#   loyalty_tier preferred_channel
# 0       Silver            Mobile
# 1       Silver            Mobile
# 2       Silver            Mobile
# 3       Silver            Mobile
# 4       Silver            Mobile

# %%
from sklearn.preprocessing import OrdinalEncoder

final_df['loyalty_tier_encoded'] = OrdinalEncoder(
    categories=[['Bronze', 'Silver', 'Gold', 'Platinum']]
).fit_transform(final_df[['loyalty_tier']])
final_df.head()
df =final_df

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# ----- 1. Ordinal encode loyalty_tier -----
df['loyalty_tier_encoded'] = OrdinalEncoder(
    categories=[['Bronze', 'Silver', 'Gold', 'Platinum']]
).fit_transform(df[['loyalty_tier']])

# ----- 2. Label encode category (NO one-hot) -----
le_cat = LabelEncoder()
df['category_encoded'] = le_cat.fit_transform(df['category'])

# ----- 3. One-hot encode gender + preferred_channel -----
df = pd.get_dummies(df,
                    columns=['gender', 'preferred_channel'],
                    drop_first=False)

df.head()
# Out:
#   customer_id  category year_month  total_quantity  total_spent  age  \
# 0      C00001    Beauty    2025-08               2      93.7700   41
# 1      C00001    Beauty    2025-09               2      65.0660   41
# 2      C00001    Beauty    2025-10               5     236.8900   41
# 3      C00001    Beauty    2025-12               5     105.3336   41
# 4      C00001  Clothing    2025-08               1     120.0000   41
#
#   loyalty_tier  loyalty_tier_encoded  category_encoded  gender_F  gender_M  \
# 0       Silver                   1.0                 0     False      True
# 1       Silver                   1.0                 0     False      True
# 2       Silver                   1.0                 0     False      True
# 3       Silver                   1.0                 0     False      True
# 4       Silver                   1.0                 1     False      True
#
#    gender_O  preferred_channel_InStore  preferred_channel_Mobile  \
# 0     False                      False                      True
# 1     False                      False                      True
# 2     False                      False                      True
# 3     False                      False                      True
# 4     False                      False                      True
#
#    preferred_channel_Online
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
df = df.drop(columns=['loyalty_tier'])

# %%
# Ensure proper sorting
df['year_month'] = pd.to_datetime(df['year_month'].astype(str) + '-01')
df = df.sort_values(['customer_id', 'category', 'year_month'])

# Compute cumulative spend **excluding current month**
df['cum_spent_till_this_month'] = (
    df.groupby(['customer_id', 'category'])['total_spent']
      .cumsum() - df['total_spent']
)

# First month will automatically be 0
print(df[['customer_id','category','year_month','total_spent','cum_spent_till_this_month']].head(10))
# Out:
#   customer_id     category year_month  total_spent  cum_spent_till_this_month
# 0      C00001       Beauty 2025-08-01      93.7700                     0.0000
# 1      C00001       Beauty 2025-09-01      65.0660                    93.7700
# 2      C00001       Beauty 2025-10-01     236.8900                   158.8360
# 3      C00001       Beauty 2025-12-01     105.3336                   395.7260
# 4      C00001     Clothing 2025-08-01     120.0000                     0.0000
# 5      C00001     Clothing 2025-10-01     890.1495                   120.0000
# 6      C00001     Clothing 2025-11-01      71.9800                  1010.1495
# 7      C00001     Clothing 2025-12-01     103.8700                  1082.1295
# 8      C00001  Electronics 2025-08-01     325.2800                     0.0000
# 9      C00001  Electronics 2025-09-01    1133.1600                   325.2800

# %%
df.head()
# Out:
#   customer_id  category year_month  total_quantity  total_spent  age  \
# 0      C00001    Beauty 2025-08-01               2      93.7700   41
# 1      C00001    Beauty 2025-09-01               2      65.0660   41
# 2      C00001    Beauty 2025-10-01               5     236.8900   41
# 3      C00001    Beauty 2025-12-01               5     105.3336   41
# 4      C00001  Clothing 2025-08-01               1     120.0000   41
#
#    loyalty_tier_encoded  category_encoded  gender_F  gender_M  gender_O  \
# 0                   1.0                 0     False      True     False
# 1                   1.0                 0     False      True     False
# 2                   1.0                 0     False      True     False
# 3                   1.0                 0     False      True     False
# 4                   1.0                 1     False      True     False
#
#    preferred_channel_InStore  preferred_channel_Mobile  \
# 0                      False                      True
# 1                      False                      True
# 2                      False                      True
# 3                      False                      True
# 4                      False                      True
#
#    preferred_channel_Online  cum_spent_till_this_month
# 0                     False                      0.000
# 1                     False                     93.770
# 2                     False                    158.836
# 3                     False                    395.726
# 4                     False                      0.000

# %%
df_model=df
df_model['year_month'] = pd.to_datetime(df_model['year_month'])
snapshot_date = df_model['year_month'].max() + pd.DateOffset(days=1)

# Group by customer
rfm = df_model.groupby('customer_id').agg({
    'year_month': lambda x: (snapshot_date - x.max()).days,  # Recency
    'total_quantity': 'count',                               # Frequency
    'total_spent': 'sum'                                     # Monetary
}).reset_index()

rfm.rename(columns={
    'year_month': 'recency_days',
    'total_quantity': 'frequency',
    'total_spent': 'monetary'
}, inplace=True)

print(rfm.head())
df_model = df_model.merge(rfm, on='customer_id', how='left')
# Out:
#   customer_id  recency_days  frequency    monetary
# 0      C00001             1         27  17512.3896
# 1      C00002             1         29  22592.9985
# 2      C00003             1         29  94081.6890
# 3      C00004             1         30  37965.7790
# 4      C00005             1         28  16494.7320

# %%
df_model.head()
# Out:
#   customer_id  category year_month  total_quantity  total_spent  age  \
# 0      C00001    Beauty 2025-08-01               2      93.7700   41
# 1      C00001    Beauty 2025-09-01               2      65.0660   41
# 2      C00001    Beauty 2025-10-01               5     236.8900   41
# 3      C00001    Beauty 2025-12-01               5     105.3336   41
# 4      C00001  Clothing 2025-08-01               1     120.0000   41
#
#    loyalty_tier_encoded  category_encoded  gender_F  gender_M  gender_O  \
# 0                   1.0                 0     False      True     False
# 1                   1.0                 0     False      True     False
# 2                   1.0                 0     False      True     False
# 3                   1.0                 0     False      True     False
# 4                   1.0                 1     False      True     False
#
#    preferred_channel_InStore  preferred_channel_Mobile  \
# 0                      False                      True
# 1                      False                      True
# 2                      False                      True
# 3                      False                      True
# 4                      False                      True
#
#    preferred_channel_Online  cum_spent_till_this_month  recency_days  \
# 0                     False                      0.000             1
# 1                     False                     93.770             1
# 2                     False                    158.836             1
# 3                     False                    395.726             1
# 4                     False                      0.000             1
#
#    frequency    monetary
# 0         27  17512.3896
# 1         27  17512.3896
# 2         27  17512.3896
# 3         27  17512.3896
# 4         27  17512.3896

# %%
from sklearn.preprocessing import MinMaxScaler

import numpy as np
bool_cols = ['gender_F','gender_M','gender_O','preferred_channel_InStore','preferred_channel_Mobile','preferred_channel_Online']
df_model[bool_cols] = df_model[bool_cols].astype(int)

# Numeric + RFM features
numeric_features = ['total_quantity','age','loyalty_tier_encoded','category_encoded',
                    'recency_days','frequency','monetary']

scaler = MinMaxScaler()

# Fit and transform numerical features
df_model[numeric_features] = scaler.fit_transform(df_model[numeric_features])

# Check
df_model[numeric_features].head()
# All features for LSTM
feature_cols = numeric_features + bool_cols
seq_len = 3  # previous 3 months
X_seq = []
y_seq = []

grouped = df_model.groupby(['customer_id','category'])

for _, group in grouped:
    group = group.sort_values('year_month')
    values = group[feature_cols + ['total_spent']].values  # features + target
    for i in range(seq_len, len(values)):
        # previous 3 months features
        X_seq.append(values[i-seq_len:i, :-1])
        # current month spend as target
        y_seq.append(values[i, -1])

X_seq = np.array(X_seq)  # shape: (samples, seq_len, num_features)
y_seq = np.array(y_seq)  # shape: (samples,)
print("X_seq shape:", X_seq.shape, "y_seq shape:", y_seq.shape)
# Out:
# X_seq shape: (2268, 3, 13) y_seq shape: (2268,)

# %%
# Simple chronological split
num_samples = X_seq.shape[0]
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)

X_train = X_seq[:train_size]
y_train = y_seq[:train_size]

X_val = X_seq[train_size:train_size+val_size]
y_val = y_seq[train_size:train_size+val_size]

X_test = X_seq[train_size+val_size:]
y_test = y_seq[train_size+val_size:]

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (1587, 3, 13) (340, 3, 13) (341, 3, 13)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization

num_features = X_seq.shape[2]

model = Sequential()

# 1st LSTM layer: large units, return sequences to stack
model.add(LSTM(256, input_shape=(seq_len, num_features), return_sequences=True))
model.add(Dropout(0.3))
model.add(BatchNormalization())

# 2nd LSTM layer: medium units, return sequences
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.25))
model.add(BatchNormalization())

# 3rd LSTM layer: smaller units, final output sequence
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# Dense layers for richer representation
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))

# Output layer
model.add(Dense(1))  # Predict next month spend

# Compile model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 3, 256)         │       276,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 3, 128)         │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 531,073 (2.03 MB)
#  Trainable params: 530,177 (2.02 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - loss: 7392685.5000 - mae: 1298.1089 - val_loss: 12296401.0000 - val_mae: 1513.0376
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 5959222.0000 - mae: 1154.0969 - val_loss: 11236834.0000 - val_mae: 1339.4760
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 4060400.2500 - mae: 1005.7312 - val_loss: 10000090.0000 - val_mae: 1318.3508
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4432231.0000 - mae: 1148.1305 - val_loss: 8161519.5000 - val_mae: 1233.7394
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3272614.2500 - mae: 997.6605 - val_loss: 7336392.5000 - val_mae: 1251.8048
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3691672.2500 - mae: 1048.0122 - val_loss: 4920840.5000 - val_mae: 1096.2988
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2568123.0000 - mae: 907.7677 - val_loss: 4233393.5000 - val_mae: 921.2709
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3057124.5000 - mae: 953.9143 - val_loss: 6769792.0000 - val_mae: 1299.2709
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 2819379.2500 - mae: 896.6576 - val_loss: 9569413.0000 - val_mae: 1643.9340
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3079246.0000 - mae: 893.3790 - val_loss: 3312268.7500 - val_mae: 875.7540
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1943567.7500 - mae: 798.7029 - val_loss: 3418819.7500 - val_mae: 884.2409
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 2566671.2500 - mae: 858.6978 - val_loss: 3822108.5000 - val_mae: 952.3445
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2162241.7500 - mae: 772.0439 - val_loss: 2670322.0000 - val_mae: 794.3334
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 2642068.5000 - mae: 907.0455 - val_loss: 2413187.5000 - val_mae: 788.4270
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1834717.1250 - mae: 774.3339 - val_loss: 1673630.1250 - val_mae: 625.4292
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1545266.3750 - mae: 717.5636 - val_loss: 1507533.8750 - val_mae: 596.5641
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1748352.2500 - mae: 750.7636 - val_loss: 3052756.2500 - val_mae: 808.1429
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1701210.7500 - mae: 738.2081 - val_loss: 1876473.0000 - val_mae: 691.0224
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1669874.0000 - mae: 732.2128 - val_loss: 1979917.1250 - val_mae: 624.2472
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1775806.0000 - mae: 707.9376 - val_loss: 2001082.5000 - val_mae: 682.3124
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1752642.0000 - mae: 718.8069 - val_loss: 1904759.3750 - val_mae: 632.9578
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1684715.6250 - mae: 698.8371 - val_loss: 1327489.0000 - val_mae: 607.1337
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1775419.0000 - mae: 698.1954 - val_loss: 2026069.8750 - val_mae: 677.6046
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 1620832.7500 - mae: 692.7257 - val_loss: 2126626.5000 - val_mae: 682.8459
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1169931.3750 - mae: 624.9684 - val_loss: 2348477.0000 - val_mae: 663.2217
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 1218507.5000 - mae: 649.4747 - val_loss: 1383300.3750 - val_mae: 578.5803
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1274030.7500 - mae: 610.3040 - val_loss: 2339677.2500 - val_mae: 670.1870
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1328028.5000 - mae: 641.1477 - val_loss: 2108098.0000 - val_mae: 637.7046
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1173900.1250 - mae: 597.9998 - val_loss: 1375917.5000 - val_mae: 578.7154
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1249593.3750 - mae: 651.9489 - val_loss: 2152236.5000 - val_mae: 732.4714
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1135006.8750 - mae: 602.3165 - val_loss: 1375700.7500 - val_mae: 603.8640
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1193781.8750 - mae: 590.3830 - val_loss: 1343398.1250 - val_mae: 578.5472

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# Evaluate model on test set
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.2f}")
print(f"Test MAE: {mae:.2f}")

# Predict on test set
y_pred = model.predict(X_test).flatten()

# Compute R² score
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Test RMSE: {rmse:.2f}")
print(f"Test R²: {r2:.2f}")
# Out:
# Test Loss (MSE): 634048.50
# Test MAE: 448.34
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test RMSE: 796.27
# Test R²: 0.90

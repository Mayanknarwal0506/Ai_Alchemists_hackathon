# %%
import pandas as pd

# %%
df = pd.read_csv("final_dataset.csv")
df.head()
# Out:
#   product_id category  unit_price  is_discountable store_id store_type  \
# 0      P0200     Home      106.31                1     S007     Outlet
# 1      P0140  Grocery        9.13                1     S017     Street
# 2      P0225   Beauty       16.93                0     S038       Mall
# 3      P0105  Grocery       13.08                1     S039     Street
# 4      P0103     Home      143.33                1     S023       Mall
#
#     region        city customer_id gender  age loyalty_tier preferred_channel  \
# 0  Central   Grandview      C00010      M   42       Bronze            Mobile
# 1  Central     Centrum      C00094      F   31       Bronze           InStore
# 2    South   Southport      C00164      M   25       Bronze           InStore
# 3     East  Rivermouth      C00197      F   24       Bronze            Online
# 4     East  Rivermouth      C00104      M   25         Gold           InStore
#
#   transaction_id transaction_date  channel  quantity  discount_pct
# 0       T0042714       2025-08-01  InStore         2           0.0
# 1       T0024445       2025-08-01  InStore         1           0.0
# 2       T0008413       2025-08-01   Online         2           0.0
# 3       T0037032       2025-08-01   Mobile         2           0.0
# 4       T0024521       2025-08-01  InStore         1           0.0

# %%
df.shape
# Out:
# (50000, 18)

# %%
# Convert date to datetime
df["transaction_date"] = pd.to_datetime(df["transaction_date"])

# %%
df["spend"] = df["unit_price"] * df["quantity"] * (1 - df["discount_pct"] / 100)

# %%
daily = (
    df.groupby(["customer_id", "transaction_date"])
      .agg(
          daily_spend=("spend", "sum"),
          total_qty=("quantity", "sum"),
          avg_price=("unit_price", "mean"),
          transactions=("spend", "count"),
          avg_discount=("discount_pct", "mean"),
          online_ratio=("channel", lambda x: (x == "Online").mean()),
          instore_ratio=("channel", lambda x: (x == "In-Store").mean())
      )
      .reset_index()
)

# %%
daily = daily.sort_values(["customer_id", "transaction_date"])

# %%
daily["next_30d_spend"] = (
    daily.groupby("customer_id")["daily_spend"]
         .transform(lambda x: x.shift(-1).rolling(window=30).sum())
)

# %%
daily = daily.dropna(subset=["next_30d_spend"])

# %%
daily.head()
# Out:
#    customer_id transaction_date  daily_spend  total_qty  avg_price  \
# 29      C00001       2025-09-18       593.16          2     296.58
# 30      C00001       2025-09-19        49.72          4      12.43
# 31      C00001       2025-09-21        97.61          1      97.61
# 32      C00001       2025-09-23       360.00          2     180.00
# 33      C00001       2025-09-24       500.00          2     250.00
#
#     transactions  avg_discount  online_ratio  instore_ratio  next_30d_spend
# 29             2           0.0           0.0            0.0     5351.521955
# 30             1           0.0           0.0            0.0     5318.911955
# 31             1           0.0           0.0            0.0     5465.471955
# 32             1           0.0           0.0            0.0     5951.431955
# 33             1           0.0           0.0            0.0     6443.543630

# %%
daily.shape
# Out:
# (19211, 10)

# %%
static_cols = ["customer_id", "region", "city", "gender", "age", "store_type"]

static_data = (
    df.sort_values("transaction_date")
      .groupby("customer_id")
      .last()
      .reset_index()[static_cols]
)

# %%
daily = daily.merge(static_data, on="customer_id", how="left")

# %%
daily.head()
# Out:
#   customer_id transaction_date  daily_spend  total_qty  avg_price  \
# 0      C00001       2025-09-18       593.16          2     296.58
# 1      C00001       2025-09-19        49.72          4      12.43
# 2      C00001       2025-09-21        97.61          1      97.61
# 3      C00001       2025-09-23       360.00          2     180.00
# 4      C00001       2025-09-24       500.00          2     250.00
#
#    transactions  avg_discount  online_ratio  instore_ratio  next_30d_spend  \
# 0             2           0.0           0.0            0.0     5351.521955
# 1             1           0.0           0.0            0.0     5318.911955
# 2             1           0.0           0.0            0.0     5465.471955
# 3             1           0.0           0.0            0.0     5951.431955
# 4             1           0.0           0.0            0.0     6443.543630
#
#   region       city gender  age store_type
# 0  South  Southport      M   41     Outlet
# 1  South  Southport      M   41     Outlet
# 2  South  Southport      M   41     Outlet
# 3  South  Southport      M   41     Outlet
# 4  South  Southport      M   41     Outlet

# %%
daily.shape
# Out:
# (19211, 15)

# %%
daily = daily.drop(columns=["online_ratio", "instore_ratio"])

# %%
daily.head()
# Out:
#   customer_id transaction_date  daily_spend  total_qty  avg_price  \
# 0      C00001       2025-09-18       593.16          2     296.58
# 1      C00001       2025-09-19        49.72          4      12.43
# 2      C00001       2025-09-21        97.61          1      97.61
# 3      C00001       2025-09-23       360.00          2     180.00
# 4      C00001       2025-09-24       500.00          2     250.00
#
#    transactions  avg_discount  next_30d_spend region       city gender  age  \
# 0             2           0.0     5351.521955  South  Southport      M   41
# 1             1           0.0     5318.911955  South  Southport      M   41
# 2             1           0.0     5465.471955  South  Southport      M   41
# 3             1           0.0     5951.431955  South  Southport      M   41
# 4             1           0.0     6443.543630  South  Southport      M   41
#
#   store_type
# 0     Outlet
# 1     Outlet
# 2     Outlet
# 3     Outlet
# 4     Outlet

# %%
daily.shape
# Out:
# (19211, 13)

# %%
daily.to_csv("short_term_spend_model_data.csv", index=False)
